# %% [markdown]
# # Data cleaning & processing

# %%
import pandas as pd

# %%
df=pd.read_excel("studen.xlsx")
df
# Out:
#        Name   Age      City Course College          Email        DOB  Gender
# 0       Ram  20.0     Delhi    MCA     SMS  abc@gmail.com 2002-12-12    Male
# 1     Shyam  22.0    Mumbai    BCA     SMS  cde@gmail.com 2004-12-13    Male
# 2     Rohan  21.0     Patna    BBA     SMS  dff@gmail.com 2002-12-14    Male
# 3     Rohit  15.0  Varanasi    BCA     SMS  ghf@gmail.com 2002-12-15    Male
# 4     Priti  13.0     Delhi    MCA     SMS  ggh@gmail.com 2002-12-16  Female
# 5     Pooja  23.0    Mumbai    MCA     SMS  tty@gmail.com 2002-12-17  Female
# 6   Shivam   11.0  Varanasi    BBA     SMS  gff@gmail.com 2002-12-18    Male
# 7      Aman  20.0  Varanasi    BCA     SMS  mki@gmail.com 2002-12-19    Male
# 8     Kunal  34.0     Delhi    BBA     SMS  mbb@gmail.com 2002-12-20    Male
# 9      Anna  11.0     Patna    NaN     SMS  bhy@gmail.com 2002-12-21    Male
# 10   Bhavna  23.0    Mumbai    MBA     SMS  ngf@gmail.com 2002-12-22    Male
# ...

# %%
df.isnull()
# Out:
#      Name    Age   City  Course  College  Email    DOB  Gender
# 0   False  False  False   False    False  False  False   False
# 1   False  False  False   False    False  False  False   False
# 2   False  False  False   False    False  False  False   False
# 3   False  False  False   False    False  False  False   False
# 4   False  False  False   False    False  False  False   False
# 5   False  False  False   False    False  False  False   False
# 6   False  False  False   False    False  False  False   False
# 7   False  False  False   False    False  False  False   False
# 8   False  False  False   False    False  False  False   False
# 9   False  False  False    True    False  False  False   False
# 10  False  False  False   False    False  False  False   False
# 11  False  False  False   False    False  False  False   False
# 12   True  False  False    True    False  False  False   False
# 13  False   True  False   False    False  False  False   False

# %%
df.isnull().sum()
# Out:
# Name       1
# Age        1
# City       0
# Course     2
# College    0
# Email      0
# DOB        0
# Gender     0
# dtype: int64

# %%
df.dropna()
# Out:
#        Name   Age      City Course College          Email        DOB  Gender
# 0       Ram  20.0     Delhi    MCA     SMS  abc@gmail.com 2002-12-12    Male
# 1     Shyam  22.0    Mumbai    BCA     SMS  cde@gmail.com 2004-12-13    Male
# 2     Rohan  21.0     Patna    BBA     SMS  dff@gmail.com 2002-12-14    Male
# 3     Rohit  15.0  Varanasi    BCA     SMS  ghf@gmail.com 2002-12-15    Male
# 4     Priti  13.0     Delhi    MCA     SMS  ggh@gmail.com 2002-12-16  Female
# 5     Pooja  23.0    Mumbai    MCA     SMS  tty@gmail.com 2002-12-17  Female
# 6   Shivam   11.0  Varanasi    BBA     SMS  gff@gmail.com 2002-12-18    Male
# 7      Aman  20.0  Varanasi    BCA     SMS  mki@gmail.com 2002-12-19    Male
# 8     Kunal  34.0     Delhi    BBA     SMS  mbb@gmail.com 2002-12-20    Male
# 10   Bhavna  23.0    Mumbai    MBA     SMS  ngf@gmail.com 2002-12-22    Male
# 11      Ram  20.0     Delhi    MCA     SMS  gtr@gmail.com 2002-12-23    Male

# %%
df.dropna(axis=1)
# Out:
#         City College          Email        DOB  Gender
# 0      Delhi     SMS  abc@gmail.com 2002-12-12    Male
# 1     Mumbai     SMS  cde@gmail.com 2004-12-13    Male
# 2      Patna     SMS  dff@gmail.com 2002-12-14    Male
# 3   Varanasi     SMS  ghf@gmail.com 2002-12-15    Male
# 4      Delhi     SMS  ggh@gmail.com 2002-12-16  Female
# 5     Mumbai     SMS  tty@gmail.com 2002-12-17  Female
# 6   Varanasi     SMS  gff@gmail.com 2002-12-18    Male
# 7   Varanasi     SMS  mki@gmail.com 2002-12-19    Male
# 8      Delhi     SMS  mbb@gmail.com 2002-12-20    Male
# 9      Patna     SMS  bhy@gmail.com 2002-12-21    Male
# 10    Mumbai     SMS  ngf@gmail.com 2002-12-22    Male
# 11     Delhi     SMS  gtr@gmail.com 2002-12-23    Male
# 12    Mumbai     SMS  fdr@gmail.com 2002-12-24    Male
# 13     Delhi     SMS  gth@gmail.com 2002-12-25    Male

# %%
df.fillna(0)
# Out:
#        Name   Age      City Course College          Email        DOB  Gender
# 0       Ram  20.0     Delhi    MCA     SMS  abc@gmail.com 2002-12-12    Male
# 1     Shyam  22.0    Mumbai    BCA     SMS  cde@gmail.com 2004-12-13    Male
# 2     Rohan  21.0     Patna    BBA     SMS  dff@gmail.com 2002-12-14    Male
# 3     Rohit  15.0  Varanasi    BCA     SMS  ghf@gmail.com 2002-12-15    Male
# 4     Priti  13.0     Delhi    MCA     SMS  ggh@gmail.com 2002-12-16  Female
# 5     Pooja  23.0    Mumbai    MCA     SMS  tty@gmail.com 2002-12-17  Female
# 6   Shivam   11.0  Varanasi    BBA     SMS  gff@gmail.com 2002-12-18    Male
# 7      Aman  20.0  Varanasi    BCA     SMS  mki@gmail.com 2002-12-19    Male
# 8     Kunal  34.0     Delhi    BBA     SMS  mbb@gmail.com 2002-12-20    Male
# 9      Anna  11.0     Patna      0     SMS  bhy@gmail.com 2002-12-21    Male
# 10   Bhavna  23.0    Mumbai    MBA     SMS  ngf@gmail.com 2002-12-22    Male
# ...

# %%
df1=df["Age"].fillna(df["Age"].mean())
print(df1)
# Out:
# 0     20.000000
# 1     22.000000
# 2     21.000000
# 3     15.000000
# 4     13.000000
# 5     23.000000
# 6     11.000000
# 7     20.000000
# 8     34.000000
# 9     11.000000
# 10    23.000000
# 11    20.000000
# 12    20.000000
# 13    19.461538
# Name: Age, dtype: float64

# %%
df.ffill()
# Out:
#        Name   Age      City Course College          Email        DOB  Gender
# 0       Ram  20.0     Delhi    MCA     SMS  abc@gmail.com 2002-12-12    Male
# 1     Shyam  22.0    Mumbai    BCA     SMS  cde@gmail.com 2004-12-13    Male
# 2     Rohan  21.0     Patna    BBA     SMS  dff@gmail.com 2002-12-14    Male
# 3     Rohit  15.0  Varanasi    BCA     SMS  ghf@gmail.com 2002-12-15    Male
# 4     Priti  13.0     Delhi    MCA     SMS  ggh@gmail.com 2002-12-16  Female
# 5     Pooja  23.0    Mumbai    MCA     SMS  tty@gmail.com 2002-12-17  Female
# 6   Shivam   11.0  Varanasi    BBA     SMS  gff@gmail.com 2002-12-18    Male
# 7      Aman  20.0  Varanasi    BCA     SMS  mki@gmail.com 2002-12-19    Male
# 8     Kunal  34.0     Delhi    BBA     SMS  mbb@gmail.com 2002-12-20    Male
# 9      Anna  11.0     Patna    BBA     SMS  bhy@gmail.com 2002-12-21    Male
# 10   Bhavna  23.0    Mumbai    MBA     SMS  ngf@gmail.com 2002-12-22    Male
# ...

# %%
df.bfill()
# Out:
#        Name   Age      City Course College
# 0       Ram  20.0     Delhi    MCA     SMS
# 1     Shyam  22.0    Mumbai    BCA     SMS
# 2     Rohan  21.0     Patna    BBA     SMS
# 3     Rohit  15.0  Varanasi    BCA     SMS
# 4     Priti  13.0     Delhi    MCA     SMS
# 5     Pooja  23.0    Mumbai    MCA     SMS
# 6   Shivam   11.0  Varanasi    BBA     SMS
# 7      Aman  20.0  Varanasi    BCA     SMS
# 8     Kunal  34.0     Delhi    BBA     SMS
# 9      Anna  11.0     Patna    MBA     SMS
# 10   Bhavna  23.0    Mumbai    MBA     SMS
# 11      Ram  20.0     Delhi    MCA     SMS
# 12    Vivek  20.0    Mumbai    BBA     SMS
# 13    Vivek   NaN     Delhi    BBA     SMS

# %% [markdown]
# # Detecting and Removing duplicates

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11     True
# 12    False
# 13    False
# dtype: bool

# %%
df.drop_duplicates()
# Out:
#        Name   Age      City Course College
# 0       Ram  20.0     Delhi    MCA     SMS
# 1     Shyam  22.0    Mumbai    BCA     SMS
# 2     Rohan  21.0     Patna    BBA     SMS
# 3     Rohit  15.0  Varanasi    BCA     SMS
# 4     Priti  13.0     Delhi    MCA     SMS
# 5     Pooja  23.0    Mumbai    MCA     SMS
# 6   Shivam   11.0  Varanasi    BBA     SMS
# 7      Aman  20.0  Varanasi    BCA     SMS
# 8     Kunal  34.0     Delhi    BBA     SMS
# 9      Anna  11.0     Patna    NaN     SMS
# 10   Bhavna  23.0    Mumbai    MBA     SMS
# 12      NaN  20.0    Mumbai    NaN     SMS
# 13    Vivek   NaN     Delhi    BBA     SMS

# %%
df.duplicated(subset=["Name","Age"])
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11     True
# 12    False
# 13    False
# dtype: bool

# %% [markdown]
# # String operation with .str

# %%
df["Name"].str.lower()
# Out:
# 0         ram
# 1       shyam
# 2       rohan
# 3       rohit
# 4       priti
# 5       pooja
# 6     shivam
# 7        aman
# 8       kunal
# 9        anna
# 10     bhavna
# 11        ram
# 12        NaN
# 13      vivek
# Name: Name, dtype: object

# %%
df["City"].str.contains("Delhi",case=False)
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6     False
# 7     False
# 8      True
# 9     False
# 10    False
# 11     True
# 12    False
# 13     True
# Name: City, dtype: bool

# %%
df["Email"].str.split("@")
# Out:
# 0     [abc, gmail.com]
# 1     [cde, gmail.com]
# 2     [dff, gmail.com]
# 3     [ghf, gmail.com]
# 4     [ggh, gmail.com]
# 5     [tty, gmail.com]
# 6     [gff, gmail.com]
# 7     [mki, gmail.com]
# 8     [mbb, gmail.com]
# 9     [bhy, gmail.com]
# 10    [ngf, gmail.com]
# 11    [gtr, gmail.com]
# 12    [fdr, gmail.com]
# 13    [gth, gmail.com]
# Name: Email, dtype: object

# %%
df["Email"].str.split("@gmail")
# Out:
# 0     [abc, .com]
# 1     [cde, .com]
# 2     [dff, .com]
# 3     [ghf, .com]
# 4     [ggh, .com]
# 5     [tty, .com]
# 6     [gff, .com]
# 7     [mki, .com]
# 8     [mbb, .com]
# 9     [bhy, .com]
# 10    [ngf, .com]
# 11    [gtr, .com]
# 12    [fdr, .com]
# 13    [gth, .com]
# Name: Email, dtype: object

# %%
df["Age"]=df["Age"].astype(str)
type("Age")
# Out:
# str

# %%
df["DOB"]=pd.to_datetime(df["DOB"])
df["DOB"].dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# # Apply functions

# %%
dff=df["Age Group"]=df["Age"].apply(lambda x: "Adult" if x>18 else "Minor")
dff
# Out:
# 0     Adult
# 1     Adult
# 2     Adult
# 3     Minor
# 4     Minor
# 5     Adult
# 6     Minor
# 7     Adult
# 8     Adult
# 9     Minor
# 10    Adult
# 11    Adult
# 12    Adult
# 13    Minor
# Name: Age, dtype: object

# %%
gender_map={"Male":"M","Female":"F",}
df["Gender"]=df["Gender"].map(gender_map)

# %%
print(df)
# Out:
#        Name   Age      City Course College          Email        DOB Gender
# 0       Ram  20.0     Delhi    MCA     SMS  abc@gmail.com 2002-12-12    NaN
# 1     Shyam  22.0    Mumbai    BCA     SMS  cde@gmail.com 2004-12-13    NaN
# 2     Rohan  21.0     Patna    BBA     SMS  dff@gmail.com 2002-12-14    NaN
# 3     Rohit  15.0  Varanasi    BCA     SMS  ghf@gmail.com 2002-12-15    NaN
# 4     Priti  13.0     Delhi    MCA     SMS  ggh@gmail.com 2002-12-16    NaN
# 5     Pooja  23.0    Mumbai    MCA     SMS  tty@gmail.com 2002-12-17    NaN
# 6   Shivam   11.0  Varanasi    BBA     SMS  gff@gmail.com 2002-12-18    NaN
# 7      Aman  20.0  Varanasi    BCA     SMS  mki@gmail.com 2002-12-19    NaN
# 8     Kunal  34.0     Delhi    BBA     SMS  mbb@gmail.com 2002-12-20    NaN
# 9      Anna  11.0     Patna    NaN     SMS  bhy@gmail.com 2002-12-21    NaN
# 10   Bhavna  23.0    Mumbai    MBA     SMS  ngf@gmail.com 2002-12-22    NaN
# ...

# %%
df["City"].replace({"del":"Delhi","mum":"Mumbai"})
df
# Out:
#        Name   Age      City Course College          Email        DOB Gender
# 0       Ram  20.0     Delhi    MCA     SMS  abc@gmail.com 2002-12-12    NaN
# 1     Shyam  22.0    Mumbai    BCA     SMS  cde@gmail.com 2004-12-13    NaN
# 2     Rohan  21.0     Patna    BBA     SMS  dff@gmail.com 2002-12-14    NaN
# 3     Rohit  15.0  Varanasi    BCA     SMS  ghf@gmail.com 2002-12-15    NaN
# 4     Priti  13.0     Delhi    MCA     SMS  ggh@gmail.com 2002-12-16    NaN
# 5     Pooja  23.0    Mumbai    MCA     SMS  tty@gmail.com 2002-12-17    NaN
# 6   Shivam   11.0  Varanasi    BBA     SMS  gff@gmail.com 2002-12-18    NaN
# 7      Aman  20.0  Varanasi    BCA     SMS  mki@gmail.com 2002-12-19    NaN
# 8     Kunal  34.0     Delhi    BBA     SMS  mbb@gmail.com 2002-12-20    NaN
# 9      Anna  11.0     Patna    NaN     SMS  bhy@gmail.com 2002-12-21    NaN
# 10   Bhavna  23.0    Mumbai    MBA     SMS  ngf@gmail.com 2002-12-22    NaN
# ...
